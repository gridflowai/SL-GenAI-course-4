# %% [markdown]
# ------------------------
# #### demo : document loading (html) using beautifulsoup
#
# - connect to NYT article (date)
# - extract info from the article
# ----------------------

# %% [markdown]
# ![image.png](attachment:73f45be0-b5eb-48de-b375-d19eda590c70.png)![image.png](attachment:9abb0a4f-9450-458f-89e0-9c1fe160d824.png)

# %%
import requests

# %%
r = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html')

# %%
r
# Out:
# <Response [200]>

# %%
r.text[:2000]
# Out:
# '<!DOCTYPE html>\n<!--[if (gt IE 9)|!(IE)]> <!--><html lang="en" class="no-js page-interactive section-opinion page-theme-standard tone-opinion page-interactive-default limit-small layout-xlarge app-interactive" itemid="https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html" itemtype="https://schema.org/NewsArticle" itemscope xmlns:og="http://opengraphprotocol.org/schema/"><!--<![endif]-->\n<!--[if IE 9]> <html lang="en" class="no-js ie9 lt-ie10 page-interactive section-opinion page-theme-standard tone-opinion page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<!--[if IE 8]> <html lang="en" class="no-js ie8 lt-ie10 lt-ie9 page-interactive section-opinion page-theme-standard tone-opinion page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<!--[if (lt IE 8)]> <html lang="en" class="no-js lt-ie10 lt-ie9 lt-ie8 page-interactive section-opinion page-theme-standard tone-opinion page-interactive-default limit-small layout-xlarge app-interactive" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->\n<head>\n<script>\nif (document.location.search.indexOf(\'nytapp=true\') > -1) document.documentElement.classList.add(\'nyt-hide-shell\');\nvar userAgent = window.navigator.userAgent || window.navigator.vendor || window.opera;\nvar inAndroid = userAgent.indexOf(\'nyt_android\') !== -1;\nvar iniOS = userAgent.indexOf(\'nytios\') !== -1;\nif (inAndroid || iniOS) document.documentElement.classList.add(\'nyt-hide-shell\');\n</script>\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />\n<link rel="shortcut icon" href="https://static01.nyt.com/favicon.ico" />\n<link rel="apple-touch-icon-precomposed" sizes="144×144" href="https://static01.nyt.com/images/icons/ios-ipad-144x144.png" />\n<link rel="apple-touch-icon-pr'

# %% [markdown]
# #### beautiful package

# %%
from bs4 import BeautifulSoup  
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# Collecting all of the records
results = soup.find_all('span', attrs={'class':'short-desc'})

# %%
len(results)
# Out:
# 180

# %%
results[:3]
# Out:
# [<span class="short-desc"><strong>Jan. 21 </strong>“I wasn't a fan of Iraq. I didn't want to go into Iraq.” <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span></span>,
#  <span class="short-desc"><strong>Jan. 21 </strong>“A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.” <span class="short-truth"><a href="http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/" target="_blank">(Trump was on the cover 11 times and Nixon appeared 55 times.)</a></span></span>,
#  <span class="short-desc"><strong>Jan. 23 </strong>“Between 3 million and 5 million illegal votes caused me to lose the popular vote.” <span class="short-truth"><a href="https://www.nytimes.com/2017/01/23/us/politics/donald-trump-congress-democrats.html" target="_blank">(There's no evidence of illegal voting.)</a></span></span>]

# %%
# Extracting the date
first_result = results[0]  
first_result
# Out:
# <span class="short-desc"><strong>Jan. 21 </strong>“I wasn't a fan of Iraq. I didn't want to go into Iraq.” <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span></span>

# %%
first_result.find('strong')
# Out:
# <strong>Jan. 21 </strong>

# %%
first_result.find('strong').text
# Out:
# 'Jan. 21\xa0'

# %%
first_result.find('strong').text[0:-1]
# Out:
# 'Jan. 21'

# %%
first_result.find('strong').text[0:-1] + ', 2017'
# Out:
# 'Jan. 21, 2017'

# %%
# Extracting the lie
first_result
# Out:
# <span class="short-desc"><strong>Jan. 21 </strong>“I wasn't a fan of Iraq. I didn't want to go into Iraq.” <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span></span>

# %%
first_result.contents[1]
# Out:
# "“I wasn't a fan of Iraq. I didn't want to go into Iraq.” "

# %%
first_result.contents[1][1:-2]
# Out:
# "I wasn't a fan of Iraq. I didn't want to go into Iraq."

# %%
first_result.contents[2]
# Out:
# <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span>

# %%
first_result.find('a')
# Out:
# <a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a>

# %%
first_result.find('a').text
# Out:
# '(He was for an invasion before he was against it.)'

# %%
first_result.find('a').text[1:-1]
# Out:
# 'He was for an invasion before he was against it.'

# %%
first_result.find('a')['href']
# Out:
# 'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'

# %%
records = []  

for result in results:  
    date        = result.find('strong').text[0:-1] + ', 2017'
    lie         = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url         = result.find('a')['href']
    
    records.append((date, lie, explanation, url))

# %%
len(records)
# Out:
# 180

# %%
records
# Out:
# [('Jan. 21, 2017',
#   "I wasn't a fan of Iraq. I didn't want to go into Iraq.",
#   'He was for an invasion before he was against it.',
#   'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'),
#  ('Jan. 21, 2017',
#   'A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.',
#   'Trump was on the cover 11 times and Nixon appeared 55 times.',
#   'http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/'),
#  ('Jan. 23, 2017',
#   'Between 3 million and 5 million illegal votes caused me to lose the popular vote.',
#   "There's no evidence of illegal voting.",
#   'https://www.nytimes.com/2017/01/23/us/politics/donald-trump-congress-democrats.html'),
#  ('Jan. 25, 2017',
#   'Now, the audience was the biggest ever. But this crowd was massive. Look how far back it goes. This crowd was massive.',
#   "Official aerial photos show Obama's 2009 inauguration was much more heavily attended.",
#   'https://www.nytimes.com/2017/01/21/us/politics/trump-white-house-briefing-inauguration-crowd-size.html'),
#  ('Jan. 25, 2017',
#   'Take a look at the Pew reports (which show voter fraud.)',
#   'The report never mentioned voter fraud.',
#   'https://www.nytimes.com/2017/01/24/us/politics/unauthorized-immigrant-voting-trump-lie.html'),
#  ('Jan. 25, 2017',
#   "You had millions of people that now aren't insured anymore.",
#   'The real number is less than 1 million, according to the Urban Institute.',
#   'https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html'),
#  ('Jan. 25, 2017',
#   "So, look, when President Obama was there two weeks ago making a speech, very nice speech. Two people were shot and killed during his speech. You can't have that.",
#   'There were no gun homicide victims in Chicago that day.',
#   'https://www.dnainfo.com/chicago/2017-chicago-murders/timeline?mon=1'),
#  ('Jan. 26, 2017',
#   "We've taken in tens of thousands of people. We know nothing about them. They can say they vet them. They didn't vet them. They have no papers. How can you vet somebody when you don't know anything about them and you have no papers? How do you vet them? You can't.",
#   'Vetting lasts up to two years.',
#   'https://www.nytimes.com/interactive/2017/01/29/us/refugee-vetting-process.html'),
#  ('Jan. 26, 2017',
#   "I cut off hundreds of millions of dollars off one particular plane, hundreds of millions of dollars in a short period of time. It wasn't like I spent, like, weeks, hours, less than hours, and many, many hundreds of millions of dollars. And the plane's going to be better.",
#   'Most of the cuts were already planned.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('Jan. 28, 2017',
#   'The coverage about me in the @nytimes and the @washingtonpost has been so false and angry that the Times actually apologized to its dwindling subscribers and readers.',
#   'It never apologized.',
#   'https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html'),
#  ('Jan. 29, 2017',
#   'The Cuban-Americans, I got 84 percent of that vote.',
#   'There is no support for this.',
#   'http://www.pewresearch.org/fact-tank/2016/11/15/unlike-other-latinos-about-half-of-cuban-voters-in-florida-backed-trump/'),
#  ('Jan. 30, 2017',
#   'Only 109 people out of 325,000 were detained and held for questioning. Big problems at airports were caused by Delta computer outage.',
#   'At least 746 people were detained and processed, and the Delta outage happened two days later.',
#   'http://markets.on.nytimes.com/research/stocks/news/press_release.asp?docTag=201701300400PR_NEWS_USPRX____CL99370&feedID=600&press_symbol=7311173'),
#  ('Feb. 3, 2017',
#   'Professional anarchists, thugs and paid protesters are proving the point of the millions of people who voted to MAKE AMERICA GREAT AGAIN!',
#   'There is no evidence of paid protesters.',
#   'https://www.nytimes.com/2017/01/28/nyregion/jfk-protests-trump-refugee-ban.html'),
#  ('Feb. 4, 2017',
#   'After being forced to apologize for its bad and inaccurate coverage of me after winning the election, the FAKE NEWS @nytimes is still lost!',
#   'It never apologized.',
#   'https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html'),
#  ('Feb. 5, 2017',
#   'We had 109 people out of hundreds of thousands of travelers and all we did was vet those people very, very carefully.',
#   'About 60,000 people were affected.',
#   'http://www.politifact.com/truth-o-meter/statements/2017/feb/06/donald-trump/president-trump-says-109-people-were-affected-trav/'),
#  ('Feb. 6, 2017',
#   'I have already saved more than $700 million when I got involved in the negotiation on the F-35.',
#   'Much of the price drop was projected before Trump took office.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('Feb. 6, 2017',
#   "It's gotten to a point where it is not even being reported. And in many cases, the very, very dishonest press doesn't want to report it.",
#   'Terrorism has been reported on, often in detail.',
#   'https://www.nytimes.com/2017/02/07/us/politics/the-white-house-list-of-terror-attacks-underreported-by-media.html'),
#  ('Feb. 6, 2017',
#   'The failing @nytimes was forced to apologize to its subscribers for the poor reporting it did on my election win. Now they are worse!',
#   "It didn't apologize.",
#   'https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html'),
#  ('Feb. 6, 2017',
#   "And the previous administration allowed it to happen because we shouldn't have been in Iraq, but we shouldn't have gotten out the way we got out. It created a vacuum, ISIS was formed.",
#   'The group’s origins date to 2004.',
#   'https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html'),
#  ('Feb. 7, 2017',
#   'And yet the murder rate in our country is the highest it’s been in 47 years, right? Did you know that? Forty-seven years.',
#   "It was higher in the 1980s and '90s.",
#   'http://www.politifact.com/truth-o-meter/statements/2017/feb/08/donald-trump/donald-trump-wrong-murder-rate-highest-47-years/'),
#  ('Feb. 7, 2017',
#   'I saved more than $600 million. I got involved in negotiation on a fighter jet, the F-35.',
#   'The Defense Department projected this price drop before Trump took office.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('Feb. 9, 2017',
#   'Chris Cuomo, in his interview with Sen. Blumenthal, never asked him about his long-term lie about his brave ‘service’ in Vietnam. FAKE NEWS!',
#   "It was part of Cuomo's first question.",
#   'http://transcripts.cnn.com/TRANSCRIPTS/1702/09/nday.05.html'),
#  ('Feb. 9, 2017',
#   'Sen. Richard Blumenthal now misrepresents what Judge Gorsuch told him?',
#   'The Gorsuch comments were later corroborated.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/02/10/heres-what-trump-got-wrong-on-twitter-this-week-5/?utm_term=.6fbfc4abc6e0'),
#  ('Feb. 10, 2017',
#   'I don’t know about it. I haven’t seen it. What report is that?',
#   "Trump knew about Flynn's actions for weeks.",
#   'http://www.factcheck.org/2017/02/trump-spins-flynn-facts/'),
#  ('Feb. 12, 2017',
#   'Just leaving Florida. Big crowds of enthusiastic supporters lining the road that the FAKE NEWS media refuses to mention. Very dishonest!',
#   'The media did cover it.',
#   'http://www.palmbeachpost.com/news/national-govt--politics/trump-heads-back-protesters-supporters-gather/CQXPE9NRk807XKWiDwefWK/'),
#  ('Feb. 16, 2017',
#   "We got 306 because people came out and voted like they've never seen before so that's the way it goes. I guess it was the biggest Electoral College win since Ronald Reagan.",
#   'George H.W. Bush, Bill Clinton and Barack Obama all won bigger margins in the Electoral College.',
#   'https://www.nytimes.com/2017/02/16/us/politics/trump-fact-check.html'),
#  ('Feb. 16, 2017',
#   'That’s the other thing that was wrong with the travel ban. You had Delta with a massive problem with their computer system at the airports.',
#   "Delta's problems happened two days later.",
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/02/03/what-trump-got-wrong-on-twitter-this-week-4/'),
#  ('Feb. 16, 2017',
#   'Walmart announced it will create 10,000 jobs in the United States just this year because of our various plans and initiatives.',
#   'The jobs are a result of its investment plans announced in Oct. 2016.',
#   'https://www.nytimes.com/interactive/2017/business/economy/trump-jobs.html'),
#  ('Feb. 16, 2017',
#   'When WikiLeaks, which I had nothing to do with, comes out and happens to give, they’re not giving classified information.',
#   'Not always. They have released classified information in the past.',
#   'http://www.politifact.com/truth-o-meter/article/2017/feb/16/fact-checking-donald-trumps-press-conference/'),
#  ('Feb. 16, 2017',
#   'We had a very smooth rollout of the travel ban. But we had a bad court. Got a bad decision.',
#   'The rollout was chaotic.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/02/16/fact-checking-president-trumps-news-conference/?utm_term=.517d64230dcf'),
#  ('Feb. 16, 2017',
#   'They’re giving stuff — what was said at an office about Hillary cheating on the debates. Which, by the way, nobody mentions. Nobody mentions that Hillary received the questions to the debates.',
#   'It was widely covered.',
#   'http://www.politifact.com/truth-o-meter/article/2017/feb/16/fact-checking-donald-trumps-press-conference/'),
#  ('Feb. 18, 2017',
#   'And there was no way to vet those people. There was no documentation. There was no nothing.',
#   'Refugees receive multiple background checks, taking up to two years.',
#   'https://www.nytimes.com/interactive/2017/01/29/us/refugee-vetting-process.html'),
#  ('Feb. 18, 2017',
#   "You look at what's happening in Germany, you look at what's happening last night in Sweden. Sweden, who would believe this?",
#   'Trump implied there was a terror attack in Sweden, but there was no such attack.',
#   'https://www.nytimes.com/2017/02/19/world/europe/last-night-in-sweden-trumps-remark-baffles-a-nation.html?rref=collection%2Ftimestopic%2FSweden&action=click&contentCollection=world&region=stream&module=stream_unit&version=latest&contentPlacement=7&pgtype=collection'),
#  ('Feb. 24, 2017',
#   'By the way, you folks are in here — this place is packed, there are lines that go back six blocks.',
#   'There was no evidence of long lines.',
#   'http://thehill.com/homenews/administration/320988-trump-falsely-claims-lines-go-back-6-blocks-for-cpac-speech'),
#  ('Feb. 24, 2017',
#   'ICE came and endorsed me.',
#   'Only its union did.',
#   'http://www.politifact.com/truth-o-meter/statements/2016/oct/10/donald-trump/trump-says-ice-endorsed-him/'),
#  ('Feb. 24, 2017',
#   'Obamacare covers very few people — and remember, deduct from the number all of the people that had great health care that they loved that was taken away from them — it was taken away from them.',
#   'Obamacare increased coverage by a net of about 20 million.',
#   'https://www.nytimes.com/2017/02/24/us/politics/fact-check-trump-blasts-fake-news-and-repeats-inaccurate-claims-at-cpac.html'),
#  ('Feb. 27, 2017',
#   'Since Obamacare went into effect, nearly half of the insurers are stopped and have stopped from participating in the Obamacare exchanges.',
#   'Many fewer pulled out.',
#   'http://www.heritage.org/health-care-reform/report/the-2017-health-insurance-exchanges-major-decrease-competition-and-choice'),
#  ('Feb. 27, 2017',
#   'On one plane, on a small order of one plane, I saved $725 million. And I would say I devoted about, if I added it up, all those calls, probably about an hour. So I think that might be my highest and best use.',
#   'Much of the price cut was already projected.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('Feb. 28, 2017',
#   'And now, based on our very strong and frank discussions, they are beginning to do just that.',
#   'NATO countries agreed to meet defense spending requirements in 2014.',
#   'https://www.nytimes.com/2017/03/01/us/politics/fact-check-trump-military.html'),
#  ('Feb. 28, 2017',
#   'The E.P.A.’s regulators were putting people out of jobs by the hundreds of thousands.',
#   "There's no evidence that the Waters of the United States rule caused severe job losses.",
#   'http://www.nytimes.com/2011/09/05/business/economy/a-debate-arises-on-job-creation-vs-environmental-regulation.html'),
#  ('Feb. 28, 2017',
#   'We have begun to drain the swamp of government corruption by imposing a five-year ban on lobbying by executive branch officials.',
#   "They can't lobby their former agency but can still become lobbyists.",
#   'https://www.washingtonpost.com/politics/2017/live-updates/trump-white-house/real-time-fact-checking-and-analysis-of-trumps-address-to-congress/fact-check-bans-on-lobbying/?utm_term=.ce1370a2b78d'),
#  ('March 3, 2017',
#   'It is so pathetic that the Dems have still not approved my full Cabinet.',
#   'Paperwork for the last two candidates was still not submitted to the Senate.',
#   'https://www.washingtonpost.com/news/politics/wp/2017/03/03/trump-is-blaming-the-democrats-for-cabinet-delays-that-are-normal-and-his-own-fault/?utm_term=.68b1395b9ff1'),
#  ('March 4, 2017',
#   'Terrible! Just found out that Obama had my ‘wires tapped’ in Trump Tower just before the victory. Nothing found. This is McCarthyism!',
#   "There's no evidence of a wiretap.",
#   'https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html'),
#  ('March 4, 2017',
#   'How low has President Obama gone to tap my phones during the very sacred election process. This is Nixon/Watergate. Bad (or sick) guy!',
#   "There's no evidence of a wiretap.",
#   'https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html'),
#  ('March 7, 2017',
#   '122 vicious prisoners, released by the Obama Administration from Gitmo, have returned to the battlefield. Just another terrible decision!',
#   '113 of them were released by President George W. Bush.',
#   'https://www.nytimes.com/2017/03/07/us/politics/guantanamo-bay-trump.html'),
#  ('March 13, 2017',
#   "I saved a lot of money on those jets, didn't I? Did I do a good job? More than $725 million on them.",
#   'Much of the cost cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('March 13, 2017',
#   'First of all, it covers very few people.',
#   'About 20 million people gained insurance under Obamacare.',
#   'https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html'),
#  ('March 15, 2017',
#   'On the airplanes, I saved $725 million. Probably took me a half an hour if you added up all of the times.',
#   'Much of the cost cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('March 17, 2017',
#   'I was in Tennessee — I was just telling the folks — and half of the state has no insurance company, and the other half is going to lose the insurance company.',
#   "There's at least one insurer in every Tennessee county.",
#   'https://public.tableau.com/profile/kaiser.family.foundation#!/vizhome/InsurerParticipationinthe2017IndividualMarketplace/2017InsurerParticipation'),
#  ('March 20, 2017',
#   'With just one negotiation on one set of airplanes, I saved the taxpayers of our country over $700 million.',
#   'Much of the cost cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('March 21, 2017',
#   'To save taxpayer dollars, I’ve already begun negotiating better contracts for the federal government — saving over $700 million on just one set of airplanes of which there are many sets.',
#   'Much of the cost cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('March 22, 2017',
#   'I make the statement, everyone goes crazy. The next day they have a massive riot, and death, and problems.',
#   'Riots in Sweden broke out two days later and there were no deaths.',
#   'https://www.nytimes.com/2017/02/19/world/europe/last-night-in-sweden-trumps-remark-baffles-a-nation.html'),
#  ('March 22, 2017',
#   'NATO, obsolete, because it doesn’t cover terrorism. They fixed that.',
#   'It has fought terrorism since the 1980s.',
#   'http://www.politifact.com/truth-o-meter/statements/2016/sep/27/donald-trump/donald-trump-wrong-again-about-nato-increasing-ter/'),
#  ('March 22, 2017',
#   'Well, now, if you take a look at the votes, when I say that, I mean mostly they register wrong — in other words, for the votes, they register incorrectly and/or illegally. And they then vote. You have tremendous numbers of people.',
#   "There's no evidence of widespread voter fraud.",
#   'https://www.nytimes.com/2017/01/24/us/politics/unauthorized-immigrant-voting-trump-lie.html'),
#  ('March 29, 2017',
#   'Remember when the failing @nytimes apologized to its subscribers, right after the election, because their coverage was so wrong. Now worse!',
#   "It didn't apologize.",
#   'https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html'),
#  ('March 31, 2017',
#   'We have a lot of plants going up now in Michigan that were never going to be there if I — if I didn’t win this election, those plants would never even think about going back. They were gone.',
#   'These investments were already planned.',
#   'https://www.nytimes.com/interactive/2017/business/economy/trump-jobs.html'),
#  ('April 2, 2017',
#   'And I was totally opposed to the war in the Middle East which I think finally has been proven, people tried very hard to say I wasn’t but you’ve seen that it is now improving.',
#   'He was for an invasion before he was against it.',
#   'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'),
#  ('April 2, 2017',
#   'Now, my last tweet — you know, the one that you are talking about, perhaps — was the one about being, in quotes, wiretapped, meaning surveilled. Guess what, it is turning out to be true.',
#   'There is still no evidence.',
#   'https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html'),
#  ('April 5, 2017',
#   'You have many states coming up where they’re going to have no insurance company. O.K.? It’s already happened in Tennessee. It’s happening in Kentucky. Tennessee only has half coverage. Half the state is gone. They left.',
#   'Every marketplace region in Tennessee had at least one insurer.',
#   'https://www.nytimes.com/2017/03/24/us/politics/fact-check-trumps-misleading-claims-in-health-bill-failure.html'),
#  ('April 6, 2017',
#   'If you look at the kind of cost-cutting we’ve been able to achieve with the military and at the same time ordering vast amounts of equipment — saved hundreds of millions of dollars on airplanes, and really billions, because if you take that out over a period of years it’s many billions of dollars — I think we’ve had a tremendous success.',
#   'Much of the price cuts were already projected.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('April 11, 2017',
#   'I like Steve, but you have to remember he was not involved in my campaign until very late. I had already beaten all the senators and all the governors, and I didn’t know Steve.',
#   'He knew Steve Bannon since 2011.',
#   'https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics'),
#  ('April 12, 2017',
#   "You can't do it faster, because they're obstructing. They're obstructionists. So I have people — hundreds of people that we're trying to get through. I mean you have — you see the backlog. We can't get them through.",
#   'At this point, he had not nominated anyone for hundreds of positions.',
#   'https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics'),
#  ('April 12, 2017',
#   'The New York Times said the word wiretapped in the headline of the first edition. Then they took it out of there fast when they realized.',
#   'There were separate headlines for print and web, but neither were altered.',
#   'https://www.nytimes.com/2017/03/23/us/politics/fact-check-trump-misleads-surveillance-wiretapping.html'),
#  ('April 12, 2017',
#   'The secretary general and I had a productive discussion about what more NATO can do in the fight against terrorism. I complained about that a long time ago and they made a change, and now they do fight terrorism.',
#   'NATO has been engaged in counterterrorism efforts since the 1980s.',
#   'https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics'),
#  ('April 12, 2017',
#   'Mosul was supposed to last for a week and now they’ve been fighting it for many months and so many more people died.',
#   'The campaign was expected to take months.',
#   'https://www.washingtonpost.com/news/the-fix/wp/2017/04/12/president-trumps-throughly-confusing-fox-business-interview-annotated/'),
#  ('April 16, 2017',
#   'Someone should look into who paid for the small organized rallies yesterday. The election is over!',
#   "There's no evidence of paid protesters.",
#   'https://www.nytimes.com/2017/04/15/us/politics/tax-day-march.html'),
#  ('April 18, 2017',
#   'The fake media goes, ‘Donald Trump changed his stance on China.’ I haven’t changed my stance.',
#   'He did.',
#   'https://www.nytimes.com/2017/04/14/business/china-currency-manipulation-trump.html'),
#  ('April 21, 2017',
#   "On 90 planes I saved $725 million. It's actually a little bit more than that, but it's $725 million.",
#   'Much of the price cuts were already projected.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('April 21, 2017',
#   'When WikiLeaks came out ... never heard of WikiLeaks, never heard of it.',
#   'He criticized it as early as 2010.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/04/25/fact-checking-president-trumps-pinocchio-laden-associated-press-interview/?utm_term=.33ae871d0c9c'),
#  ('April 27, 2017',
#   'I want to help our miners while the Democrats are blocking their healthcare.',
#   'The bill to extend health benefits for certain coal miners was introduced by a Democrat and was co-sponsored by mostly Democrats.',
#   'http://www.pbs.org/newshour/rundown/retired-coal-miners-get-health-care-fix-pension-problems-remain/'),
#  ('April 28, 2017',
#   'The trade deficit with Mexico is close to $70 billion, even with Canada it’s $17 billion trade deficit with Canada.',
#   'The U.S. had an $8.1 billion trade surplus, not deficit, with Canada in 2016.',
#   'http://www.factcheck.org/2017/05/trumps-100-day-boasts/'),
#  ('April 28, 2017',
#   "She's running against someone who's going to raise your taxes to the sky, destroy your health care, and he's for open borders — lots of crime.",
#   "Those are not Jon Ossoff's positions.",
#   'http://www.mdjonline.com/opinion/jon-ossoff-voters-too-smart-to-believe-attack-ads/article_d6c9dafa-1e5a-11e7-a93c-c7e0b4d4f985.html'),
#  ('April 28, 2017',
#   'The F-35 fighter jet program — it was way over budget. I’ve saved $725 million plus, just by getting involved in the negotiation.',
#   'Much of the price cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('April 29, 2017',
#   "As you know, I've been a big critic of China, and I've been talking about currency manipulation for a long time. But I have to tell you that during the election, number one, they stopped.",
#   'China stopped years ago.',
#   'https://www.nytimes.com/2017/04/07/world/asia/fact-check-trump-china-trade.html'),
#  ('April 29, 2017',
#   "I've already saved more than $725 million on a simple order of F-35 planes. I got involved in the negotiation.",
#   'Much of the price cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('April 29, 2017',
#   "We're also getting NATO countries to finally step up and contribute their fair share. They've begun to increase their contributions by billions of dollars, but we are not going to be satisfied until everyone pays what they owe.",
#   'The deal was struck in 2014.',
#   'https://www.nytimes.com/2017/03/01/us/politics/fact-check-trump-military.html'),
#  ('April 29, 2017',
#   'When they talk about currency manipulation, and I did say I would call China, if they were, a currency manipulator, early in my tenure. And then I get there. Number one, they — as soon as I got elected, they stopped.',
#   'China stopped in 2014.',
#   'https://www.nytimes.com/2017/04/07/world/asia/fact-check-trump-china-trade.html'),
#  ('April 29, 2017',
#   'I was negotiating to reduce the price of the big fighter jet contract, the F-35, which was totally out of control. I will save billions and billions and billions of dollars.',
#   'Most of the cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('April 29, 2017',
#   "I think our side's been proven very strongly. And everybody's talking about it.",
#   "There's still no evidence Trump's phones were tapped.",
#   'https://www.nytimes.com/2017/03/20/us/politics/intelligence-committee-russia-donald-trump.html'),
#  ('May 1, 2017',
#   "Well, we are protecting pre-existing conditions. And it'll be every good — bit as good on pre-existing conditions as Obamacare.",
#   'The bill weakens protections for people with pre-existing conditions.',
#   'https://www.nytimes.com/2017/04/26/upshot/what-changed-in-the-health-repeal-plan-to-win-over-the-freedom-caucus.html'),
#  ('May 1, 2017',
#   "The F-35 fighter jet — I saved — I got involved in the negotiation. It's 2,500 jets. I negotiated for 90 planes, lot 10. I got $725 million off the price.",
#   'Much of the price cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('May 1, 2017',
#   "First of all, since I started running, they haven't increased their — you know, they have not manipulated their currency. I think that was out of respect to me and the campaign.",
#   'China stopped years ago.',
#   'https://www.nytimes.com/2017/04/07/world/asia/fact-check-trump-china-trade.html'),
#  ('May 2, 2017',
#   'I love buying those planes at a reduced price. I have been really — I have cut billions — I have to tell you this, and they can check, right, Martha? I have cut billions and billions of dollars off plane contracts sitting here.',
#   'Much of the cost cuts were planned before Trump.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('May 4, 2017',
#   'Number two, they’re actually not a currency [manipulator]. You know, since I’ve been talking about currency manipulation with respect to them and other countries, they stopped.',
#   'China stopped years ago.',
#   'https://www.nytimes.com/2017/04/07/world/asia/fact-check-trump-china-trade.html'),
#  ('May 4, 2017',
#   'We’re the highest-taxed nation in the world.',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('May 4, 2017',
#   'Nobody cares about my tax return except for the reporters.',
#   'Polls show most Americans do care.',
#   'http://time.com/money/4732925/trump-tax-returns-released-poll/'),
#  ('May 8, 2017',
#   'You know we’ve gotten billions of dollars more in NATO than we’re getting. All because of me.',
#   'The deal was struck in 2014.',
#   'https://www.nytimes.com/2017/03/01/us/politics/fact-check-trump-military.html'),
#  ('May 8, 2017',
#   'But when I did his show, which by the way was very highly rated. It was high — highest rating. The highest rating he’s ever had.',
#   "Colbert's Late Show debut had nearly two million more viewers.",
#   'http://money.cnn.com/2017/05/11/media/stephen-colbert-trump-no-talent-comment/'),
#  ('May 8, 2017',
#   'Director Clapper reiterated what everybody, including the fake media already knows — there is ‘no evidence’ of collusion w/ Russia and Trump.',
#   "Clapper only said he wasn't aware of an investigation.",
#   'https://www.nytimes.com/2017/05/10/us/politics/fact-check-fbi-james-comey-sarah-huckabee-sanders.html'),
#  ('May 12, 2017',
#   'Again, the story that there was collusion between the Russians & Trump campaign was fabricated by Dems as an excuse for losing the election.',
#   'The F.B.I. was investigating before the election.',
#   'https://www.nytimes.com/interactive/2017/05/10/us/politics/fbi-congress-trump-russia-investigations.html'),
#  ('May 12, 2017',
#   'When James Clapper himself, and virtually everyone else with knowledge of the witch hunt, says there is no collusion, when does it end?',
#   "Clapper said he wouldn't have been told of an investigation into collusion.",
#   'https://www.nytimes.com/2017/05/10/us/politics/fact-check-fbi-james-comey-sarah-huckabee-sanders.html'),
#  ('May 13, 2017',
#   "I'm cutting the price of airplanes with Lockheed.",
#   'The cost cuts were planned before he became president.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/'),
#  ('May 26, 2017',
#   'Just arrived in Italy for the G7. Trip has been very successful. We made and saved the USA many billions of dollars and millions of jobs.',
#   "He's referencing an arms deal that's not enacted and other apparent deals that weren't announced on the trip.",
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/05/26/president-trumps-claim-that-hes-already-saved-millions-of-jobs-on-his-foreign-trip/?utm_term=.820dd5955428'),
#  ('June 1, 2017',
#   'China will be allowed to build hundreds of additional coal plants. So, we can’t build the plants, but they can, according to this agreement. India will be allowed to double its coal production by 2020.',
#   'The agreement doesn’t allow or disallow building coal plants.',
#   'https://www.washingtonpost.com/news/the-fix/wp/2017/06/01/transcript-president-trumps-remarks-on-leaving-the-paris-climate-deal-annotated/?utm_term=.7f974232c4ba'),
#  ('June 1, 2017',
#   'I’ve just returned from a trip overseas where we concluded nearly $350 billion of military and economic development for the United States, creating hundreds of thousands of jobs.',
#   'Trump’s figures are inflated and premature.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/06/08/the-trump-administrations-tally-of-350-billion-plus-in-deals-with-saudi-arabia/?utm_term=.142db3117855'),
#  ('June 4, 2017',
#   'At least 7 dead and 48 wounded in terror attack and Mayor of London says there is ‘no reason to be alarmed!’',
#   'The mayor was specifically talking about the enlarged police presence on the streets.',
#   'http://www.snopes.com/2017/06/04/london-mayor-sadiq-khan-no-reason-to-be-alarmed-trump/'),
#  ('June 5, 2017',
#   'The Justice Dept. should have stayed with the original Travel Ban, not the watered down, politically correct version they submitted to S.C.',
#   'Trump signed this version of the travel ban, not the Justice Department.',
#   'http://www.factcheck.org/2017/06/trumps-tweets-twist-facts/'),
#  ('June 20, 2017',
#   'Well, the Special Elections are over and those that want to MAKE AMERICA GREAT AGAIN are 5 and O!',
#   'Republicans have won four special elections this year, while a Democrat won one.',
#   'https://www.washingtonpost.com/news/the-fix/wp/2017/06/21/republicans-claim-a-big-victory-and-trump-promptly-exaggerates-it/?utm_term=.ce22a6dade36'),
#  ('June 21, 2017',
#   "They all say it's 'nonbinding.' Like hell it's nonbinding.",
#   'The Paris climate agreement is nonbinding — and Trump said so in his speech announcing the withdrawal.',
#   'https://www.nytimes.com/2017/06/21/us/politics/trump-iowa-rally-venting-session.html'),
#  ('June 21, 2017',
#   'Right now, we are one of the highest-taxed nations in the world.',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/article/2017/jun/22/fact-checking-nine-things-trump-overstated-got-wro/'),
#  ('June 21, 2017',
#   'You have a gang called MS-13. ... We are moving them out of the country by the thousands, by the thousands.',
#   'The real number of gang members deported is smaller.',
#   'http://www.factcheck.org/2017/06/factchecking-trumps-iowa-rally'),
#  ('June 21, 2017',
#   'Your insurance companies have all fled the state of Iowa.',
#   "They haven't.",
#   'http://www.factcheck.org/2017/06/factchecking-trumps-iowa-rally/'),
#  ('June 21, 2017',
#   "If [farmers] have a puddle in the middle of their field ... it's considered a lake and you can't touch it. ... We got rid of that one, too, O.K.?",
#   'The Obama environmental rule to limit pollution in the country’s waters explicitly excludes puddles.',
#   'https://www.nytimes.com/2017/06/22/us/politics/factcheck-donald-trump-iowa-rally.html'),
#  ('June 21, 2017',
#   'Gary Cohn just paid $200 million in tax in order to take this job, by the way.',
#   'Cohn sold Goldman Sachs stock worth $220 million.',
#   'https://www.nytimes.com/2017/06/22/us/politics/factcheck-donald-trump-iowa-rally.html'),
#  ('June 21, 2017',
#   'We’re 5 and 0.',
#   'Republicans have won four special elections this year, while a Democrat won one.',
#   'https://www.washingtonpost.com/graphics/politics/trump-claims-database/?utm_term=.60ce71155f60'),
#  ('June 21, 2017',
#   'Last week a brand-new coal mine just opened in the state of Pennsylvania, first time in decades, decades.',
#   'Another coal mine opened in 2014.',
#   'https://www.washingtonpost.com/graphics/politics/trump-claims-database/?utm_term=.60ce71155f60'),
#  ('June 22, 2017',
#   'Former Homeland Security Advisor Jeh Johnson is latest top intelligence official to state there was no grand scheme between Trump & Russia.',
#   "Johnson, who had a different title, didn't say that.",
#   'http://talkingpointsmemo.com/livewire/trump-claims-johnson-testimony-clears-him'),
#  ('June 23, 2017',
#   'We are 5 and 0 ... in these special elections.',
#   'Republicans have won four special elections this year, while a Democrat won one.',
#   'http://www.chicagotribune.com/news/nationworld/politics/factcheck/ct-fact-check-trump-missions-20170624-story.html'),
#  ('June 27, 2017',
#   'Ratings way down!',
#   "CNN's ratings were at a five-year high at the time.",
#   'http://www.politifact.com/truth-o-meter/statements/2017/jul/03/donald-trump/trumps-pants-fire-claim-cnn-ratings-are-way-down/'),
#  ('June 28, 2017',
#   'Democrats purposely misstated Medicaid under new Senate bill — actually goes up.',
#   'Senate bill would have cut the program deeply.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/06/30/president-trumps-claim-medicaid-spending-in-senate-health-bill-actually-goes-up/?utm_term=.a319dee54870'),
#  ('June 29, 2017',
#   'General Kelly and his whole group — they’ve gotten rid of 6,000 so far.',
#   'The real number of MS-13 gang members who have been deported is smaller.',
#   'https://www.washingtonpost.com/graphics/politics/trump-claims-database/?utm_term=.aa961e129167'),
#  ('July 6, 2017',
#   'As a result of this insistence, billions of dollars more have begun to pour into NATO.',
#   'NATO countries agreed to meet defense spending requirements in 2014.',
#   'http://www.nbcnews.com/politics/donald-trump/fact-check-long-trump-took-credit-nato-spending-was-n780241'),
#  ('July 17, 2017',
#   'We’ve signed more bills — and I’m talking about through the legislature — than any president, ever.',
#   'Clinton, Carter, Truman, and F.D.R. had signed more at the same point.',
#   'https://www.nytimes.com/2017/07/17/us/politics/trump-laws-bills.html'),
#  ('July 19, 2017',
#   'Um, the Russian investigation — it’s not an investigation, it’s not on me — you know, they’re looking at a lot of things.',
#   'It is.',
#   'http://time.com/4823514/donald-trump-investigation-jay-sekulow/'),
#  ('July 19, 2017',
#   'I heard that Harry Truman was first, and then we beat him. These are approved by Congress. These are not just executive orders.',
#   'Presidents Clinton, Carter, Truman, and F.D.R. each had signed more legislation than Trump at the same point in their terms.',
#   'https://www.nytimes.com/2017/07/17/us/politics/trump-laws-bills.html'),
#  ('July 19, 2017',
#   'But the F.B.I. person really reports directly to the president of the United States, which is interesting.',
#   'He reports directly to the attorney general.',
#   'https://www.usatoday.com/story/news/politics/onpolitics/2017/07/20/fbi-director-reports-justice-department-not-president/495094001/'),
#  ('July 19, 2017',
#   'She did the uranium deal, which is a horrible thing, while she was secretary of state, and got a lot of money.',
#   "There's no evidence Hillary Clinton was actively involved or benefited from the deal.",
#   'http://www.factcheck.org/2017/10/facts-uranium-one/'),
#  ('July 24, 2017',
#   'It looks like about 45,000 people. You set a record today.',
#   'Many fewer than 45,000 were there, and the attendance was not a record.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/07/26/26-hours-29-trumpian-false-or-misleading-claims/?utm_term=.2e4b2407199f'),
#  ('July 25, 2017',
#   'We have the highest taxes anywhere in the world, and this will really bring them down to one of the lowest.',
#   'Tax rates in the United States are below average, overall and for an industrialized country.',
#   'http://www.politifact.com/truth-o-meter/statements/2017/oct/18/donald-trump/once-again-trump-overstates-us-tax-ranking/'),
#  ('July 25, 2017',
#   'We’re the highest-taxed nation in the world',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2017/oct/18/donald-trump/once-again-trump-overstates-us-tax-ranking/'),
#  ('July 25, 2017',
#   'We have nearly doubled the number of veterans given approvals to see the doctor of their choice.',
#   'The increase was 26 percent.',
#   'https://www.usatoday.com/story/opinion/2017/07/24/veterans-health-care-will-not-be-privatized-david-shulkin-column/499417001/'),
#  ('July 25, 2017',
#   'Since I took office we have cut illegal immigration on our southern border by record numbers. 78 percent.',
#   "The decline began before Trump's inauguration.",
#   'https://www.nytimes.com/interactive/2017/10/12/us/politics/trump-border-claim-factcheck.html?_r=0'),
#  ('July 28, 2017',
#   'The previous administration enacted an open-door policy to illegal migrants from Central America.  "Welcome in. Come in, please, please.',
#   'Obama deported millions.',
#   'http://www.politifact.com/truth-o-meter/article/2017/jul/28/fact-checking-donald-trumps-ny-speech-law-enforcem/'),
#  ('July 28, 2017',
#   'We have trade deficits with almost every country because we had a lot of really bad negotiators making deals with other countries.',
#   'The U.S. has a trade surplus with more than 100 countries.',
#   'https://www.bea.gov/newsreleases/international/trade/2017/trad0917.htm'),
#  ('July 31, 2017',
#   '2.6 is a number that nobody thought they’d see for a long period of time.',
#   'Many experts predicted economic growth at least this high.',
#   'http://www.factcheck.org/2017/08/trumps-gdp-puffery/'),
#  ('July 31, 2017',
#   'And even the President of Mexico called me  – they said their southern border, very few people are coming because they know they’re not going to get through our border, which is the ultimate compliment.',
#   "Mexico's president says he didn't call Trump.",
#   'http://www.cnn.com/2017/08/02/politics/trump-phone-calls/index.html'),
#  ('Aug. 1, 2017',
#   "And I think to me, maybe the biggest is that GDP for the quarter just released at 2.6 percent. So that's so much higher than anticipated.",
#   "It wasn't.",
#   'http://www.factcheck.org/2017/08/trumps-gdp-puffery/'),
#  ('Aug. 3, 2017',
#   'Economic growth has surged to 2.6% nationwide. You have to understand what that means. Nobody thought that number was going to happen.',
#   'Many experts predicted that.',
#   'https://www.usatoday.com/story/news/politics/2017/08/04/fact-checking-donald-trumps-west-virginia-rally/541318001/'),
#  ('Aug. 3, 2017',
#   'The Russia story is a total fabrication.',
#   "It's not.",
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/08/03/fact-checking-the-trump-russia-investigation/?utm_term=.1404a36076a6'),
#  ('Aug. 3, 2017',
#   'Or let them look at the uranium she sold that is now in the hands of very angry Russians.',
#   "There's no evidence Hillary Clinton was actively involved in the sale.",
#   'http://www.factcheck.org/2017/08/factchecking-trumps-west-virginia-rally/'),
#  ('Aug. 15, 2017',
#   "We want products made in the country. Now, I have to tell you, some of the folks that will leave, they're leaving out of embarrassment because they make their products outside.",
#   "People resigned from Trump's business councils over his Charlottesville comments.",
#   'http://money.cnn.com/2017/08/16/news/trump-manufacturing-council-ceos/index.html'),
#  ('Aug. 22, 2017',
#   'Remember, everybody said you won’t bring it up to 1 percent. You won’t bring it up to 1.2 percent.',
#   'Many experts predicted economic growth at least this high.',
#   'https://washingtonmonthly.com/2017/08/23/quick-takes-how-many-lies-did-trump-tell-last-night/'),
#  ('Aug. 22, 2017',
#   "I mean truly dishonest people in the media and the fake media, they make up stories. They have no sources in many cases. They say 'a source says'  – there is no such thing.",
#   'The media does not make up sources.',
#   'http://www.factcheck.org/2017/02/factchecking-trumps-cpac-speech/'),
#  ('Aug. 22, 2017',
#   'As everybody here remembers, this was the scene of my first rally speech, right?',
#   "Trump's first rally was in New Hampshire",
#   'https://www.realclearpolitics.com/articles/2015/06/18/at_trumps_nh_rally_true_believers_and_big_fans_127030.html'),
#  ('Aug. 22, 2017',
#   'We have become an energy exporter for the first time ever just recently.',
#   "The U.S. isn't projected to become a net energy exporter until 2026.",
#   'http://www.politifact.com/truth-o-meter/statements/2017/aug/23/donald-trump/donald-trump-wrongly-says-us-net-energy-exporte/'),
#  ('Aug. 22, 2017',
#   "Look back there, the live red lights. They're turning those suckers off fast out there. They're turning those lights off fast. Like CNN.",
#   "CNN didn't turn off its cameras.",
#   'http://www.cnn.com/2017/08/23/politics/phoenix-rally-things-trump-got-wrong/index.html'),
#  ('Sept. 6, 2017',
#   'The taxes are crazy  – the highest-taxed nation in the world.',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Sept. 6, 2017',
#   'We are the highest taxed nation in the world - that will change.',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Sept. 8, 2017',
#   'Our incredible U.S. Coast Guard saved more than 15,000 lives last week with Harvey.',
#   'The real number is 11,022.',
#   'https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3'),
#  ('Sept. 14, 2017',
#   "Also with the fact that I know in the case of FEMA and the case of Coast Guard, the job you've done in saving people, saving lives.  As an example, in Harvey in Texas, we talked  – over 16,000 lives.",
#   'The real number is smaller.',
#   'https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3'),
#  ('Sept. 14, 2017',
#   'And in Florida you got hit with the strongest winds ever recorded.',
#   "They weren't the strongest ever recorded.",
#   'https://www.washingtonpost.com/news/post-nation/wp/2017/09/09/destructive-winds-rain-hit-florida-as-hurricane-irma-approaches/'),
#  ('Sept. 22, 2017',
#   "We've been dealing with ICE, we've been dealing with the Border Patrol. They both endorsed me.",
#   'Neither agency endorsed him; only their unions did.',
#   'http://www.politifact.com/truth-o-meter/statements/2016/oct/10/donald-trump/trump-says-ice-endorsed-him/'),
#  ('Sept. 22, 2017',
#   "So he started off here, he was in third or fourth, he went to third, second, and now it's like almost pretty even.",
#   'Strange consistently polled first or second in the Alabama Republican primary.',
#   'https://www.realclearpolitics.com/epolls/2017/senate/al/alabama_senate_special_election_republican_primary-6220.html#polls'),
#  ('Sept. 29, 2017',
#   "With the F-35 fighter plane  – me, myself  – I've saved hundreds of millions of dollars in negotiating.",
#   'The cost cuts were planned before he became president.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/?utm_term=.ef182851faef'),
#  ('Sept. 27, 2017',
#   'I’m doing the right thing, and it’s not good for me.',
#   'All available evidence suggests he would benefit.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/09/28/fact-checking-president-trumps-tax-speech-in-indianapolis/?utm_term=.1c2a17457496'),
#  ('Sept. 27, 2017',
#   'To protect millions of small businesses and the American farmer, we are finally ending the crushing, the horrible, the unfair estate tax.',
#   'The real number of small businesses and farmers is vastly smaller.',
#   'http://www.politifact.com/truth-o-meter/statements/2017/sep/28/donald-trump/donald-trumps-pants-fire-claim-about-estate-tax-sm/'),
#  ('Sept. 27, 2017',
#   "No, I don't benefit. I don't benefit. In fact, very very strongly, as you see, I think there's very little benefit for people of wealth.",
#   'The tax plan would personally benefit Trump\xa0and other wealthy individuals.',
#   'http://www.politifact.com/truth-o-meter/statements/2017/sep/28/donald-trump/donald-trumps-dubious-claim-his-tax-plan-wont-bene/'),
#  ('Sept. 27, 2017',
#   'Facebook was always anti-Trump.The Networks were always anti-Trump hence,Fake News, @nytimes(apologized) & @WaPo were anti-Trump.',
#   'The Times did not apologize for its Trump coverage.',
#   'https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html'),
#  ('Sept. 28, 2017',
#   "I mean right now, we're the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 3, 2017',
#   'But the Coast Guard itself saved in Texas 16,000 lives, and they went right through that hurricane.',
#   'The real number is smaller.',
#   'https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3'),
#  ('Oct. 3, 2017',
#   "But that's an expensive plane that you can't see. And as you probably heard, we cut the price very substantially  – something that other administrations would never have done, that I can tell you.",
#   'The cost cuts were planned before he became president.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/?utm_term=.ef182851faef'),
#  ('Oct. 6, 2017',
#   'I was able to reduce the price of the Lockheed by billions of dollars.',
#   'The cost cuts were planned before he became president.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/?utm_term=.ef182851faef'),
#  ('Oct. 6, 2017',
#   "We're the highest-taxed developed nation in the world, probably the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 6, 2017',
#   'They also just said that there has been absolutely no collusion. They just said that. Yesterday. Two days ago. Senate. There has been no collusion.',
#   "The Senate didn't say that.",
#   'http://www.cnn.com/TRANSCRIPTS/1710/04/ip.02.html'),
#  ('Oct. 6, 2017',
#   "This tax cut and tax reform is going very well, and it's going to be a tremendous boost for our country, including the fact that we're the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 7, 2017',
#   "We're the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 7, 2017',
#   'The Coast Guard, in Texas, and all over, but with the job they did in Texas, I saw, they saved 16,000 lives.',
#   'The real number is smaller.',
#   'https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3'),
#  ('Oct. 7, 2017',
#   "Obama should have never gotten out the way he got out. That's how ISIS formed.",
#   'The group’s origins date to 2004.',
#   'https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html'),
#  ('Oct. 10, 2017',
#   "The Failing @nytimes set Liddle' Bob Corker up by recording his conversation. Was made to sound a fool, and that's what I am dealing with!",
#   'Corker asked the Times reporter to record the call; his aides recorded it too.',
#   'https://www.nytimes.com/2017/10/10/reader-center/trump-claims-we-tricked-bob-corker-heres-the-truth.html?_r=0'),
#  ('Oct. 10, 2017',
#   "We're the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 11, 2017',
#   "We have missiles that can knock out a missile in the air. Ninety seven per cent of the time. If you send two of them, it's going to get knocked out.",
#   'The effectiveness rate is about 60 percent.',
#   'https://warontherocks.com/2017/10/deadly-overconfidence-trump-thinks-missile-defenses-work-against-north-korea-and-that-should-scare-you/'),
#  ('Oct. 16, 2017',
#   "We're the highest-taxed country in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 16, 2017',
#   'I hear that Ireland is going to be reducing their corporate rates down to 8 percent from 12.',
#   'Ireland has no plans to cut its tax rate.',
#   'https://www.snopes.com/trump-ireland-tax/'),
#  ('Oct. 16, 2017',
#   'If you look at President Obama and other presidents, most of them didn’t make calls.',
#   'They did call families of soldiers killed in action.',
#   'https://www.nytimes.com/2017/10/16/us/politics/trump-obama-killed-soldiers.html'),
#  ('Oct. 16, 2017',
#   "All I can say is it's totally fake news, just fake. It's fake. It's made-up stuff, and it's disgraceful what happens, but that happens in the world of politics.",
#   'Trump himself has bragged about groping women.',
#   'https://www.washingtonpost.com/news/fact-checker/wp/2017/10/27/trump-says-sex-harassment-claims-are-fake-news-but-there-are-corroborators/?utm_term=.23c3b28384e2'),
#  ('Oct. 17, 2017',
#   "We're the highest taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 17, 2017',
#   'Right now, we are the highest-taxed nation anywhere in the world. You can even say developed or undeveloped.',
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 17, 2017',
#   "As far as I'm concerned, I think we're really essentially the highest. But if you'd like to add the developed nation, you can say that, too.",
#   'Taxes in the U.S. are lower than in most developed countries.',
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 17, 2017',
#   "We're the highest-taxed nation in the world. We are taxed beyond belief.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 17, 2017',
#   "Well, we're the highest-taxed nation in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Oct. 17, 2017',
#   "I wish President Obama didn't get out the way he got out. Because that left a vacuum and ISIS was formed.",
#   'The group’s origins date to 2004.',
#   'https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html'),
#  ('Oct. 18, 2017',
#   'Democrat Congresswoman totally fabricated what I said to the wife of a soldier who died in action (and I have proof).',
#   "The wife confirmed Representative Frederica Wilson's account.",
#   'http://time.com/4993045/myeshia-johnson-donald-trump-frederica-wilson/'),
#  ('Oct. 18, 2017',
#   'The Coast Guard in Texas saved 16,000 lives.',
#   'The real number was smaller.',
#   'https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3'),
#  ('Oct. 18, 2017',
#   'Nobody has ever heard of a five hitting land.',
#   'Category 5 storms have hit land before.',
#   'http://www.cnn.com/2017/09/07/us/three-category-5-hurricanes-landfall-trnd/index.html'),
#  ('Oct. 24, 2017',
#   'Under our plan, more than 30 million Americans who own small businesses will get a 40 per cent cut to their top marginal tax rate.',
#   'The real number is estimated to be less than 1 million.',
#   'http://www.businessinsider.com/trump-small-business-tax-cut-pass-through-s-corporations-2017-10'),
#  ('Oct. 25, 2017',
#   'We have trade deficits with almost everybody.',
#   'We have trade surpluses with more than 100 countries.',
#   'https://www.bea.gov/newsreleases/international/trade/2017/trad0917.htm'),
#  ('Oct. 27, 2017',
#   'Wacky & totally unhinged Tom Steyer, who has been fighting me and my Make America Great Again agenda from beginning, never wins elections!',
#   'Steyer has financially supported many winning candidates.',
#   'https://www.opensecrets.org/donor-lookup/results?name=Thomas+Steyer'),
#  ('Nov. 1, 2017',
#   "Again, we're the highest-taxed nation, just about, in the world.",
#   "We're not.",
#   'http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/'),
#  ('Nov. 7, 2017',
#   "When you look at the city with the strongest gun laws in our nation, it's Chicago.",
#   'Several other cities, including New York and Los Angeles, have stronger gun laws.',
#   'http://www.politifact.com/truth-o-meter/statements/2017/nov/07/donald-trump/trump-wrongly-repeats-chicago-has-strongest-gun-la/'),
#  ('Nov. 11, 2017',
#   "I'd rather have him  – you know, work with him on the Ukraine than standing and arguing about whether or not  – because that whole thing was set up by the Democrats.",
#   'There is no evidence that Democrats "set up" Russian interference in the election.',
#   'https://www.nytimes.com/interactive/2017/12/10/us/politics/trump-and-russia.html')]

# %%
# Applying a tabular data structure
import pandas as pd  
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])

# %%
df.head()
# Out:
#             date                                                lie  \
# 0  Jan. 21, 2017  I wasn't a fan of Iraq. I didn't want to go in...
# 1  Jan. 21, 2017  A reporter for Time magazine — and I have been...
# 2  Jan. 23, 2017  Between 3 million and 5 million illegal votes ...
# 3  Jan. 25, 2017  Now, the audience was the biggest ever. But th...
# 4  Jan. 25, 2017  Take a look at the Pew reports (which show vot...
#
#                                          explanation  \
# 0   He was for an invasion before he was against it.
# 1  Trump was on the cover 11 times and Nixon appe...
# 2             There's no evidence of illegal voting.
# 3  Official aerial photos show Obama's 2009 inaug...
# 4            The report never mentioned voter fraud.
#
#                                                  url
# 0  https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1  http://nation.time.com/2013/11/06/10-things-yo...
# 2  https://www.nytimes.com/2017/01/23/us/politics...
# 3  https://www.nytimes.com/2017/01/21/us/politics...
# 4  https://www.nytimes.com/2017/01/24/us/politics...

# %%
df.columns
# Out:
# Index(['date', 'lie', 'explanation', 'url'], dtype='object')

# %%
from llama_index.core import Document

# %%
# Convert DataFrame rows to LlamaIndex documents
documents = [
    Document(text=f"Date: {row['date']}\nLie: {row['lie']}\nExplanation: {row['explanation']}\nURL: {row['url']}")
    for _, row in df.iterrows()
]

# %%
documents
# Out:
# [Document(id_='79a681c9-81d2-424d-abde-7a386bad2cbd', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 21, 2017\nLie: I wasn't a fan of Iraq. I didn't want to go into Iraq.\nExplanation: He was for an invasion before he was against it.\nURL: https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='55b7032c-b7ec-4d99-a49f-cdbe499c664e', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Jan. 21, 2017\nLie: A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.\nExplanation: Trump was on the cover 11 times and Nixon appeared 55 times.\nURL: http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='66d673dd-95b6-45d1-89d5-524caee8e6af', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 23, 2017\nLie: Between 3 million and 5 million illegal votes caused me to lose the popular vote.\nExplanation: There's no evidence of illegal voting.\nURL: https://www.nytimes.com/2017/01/23/us/politics/donald-trump-congress-democrats.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0a3cec8b-84e3-4797-be90-0de0164b3c93', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 25, 2017\nLie: Now, the audience was the biggest ever. But this crowd was massive. Look how far back it goes. This crowd was massive.\nExplanation: Official aerial photos show Obama's 2009 inauguration was much more heavily attended.\nURL: https://www.nytimes.com/2017/01/21/us/politics/trump-white-house-briefing-inauguration-crowd-size.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9d24d1b3-1fda-453d-b798-af36a5d313ff', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Jan. 25, 2017\nLie: Take a look at the Pew reports (which show voter fraud.)\nExplanation: The report never mentioned voter fraud.\nURL: https://www.nytimes.com/2017/01/24/us/politics/unauthorized-immigrant-voting-trump-lie.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='00f0f230-fe4d-49e8-8e26-030b3d1a5e99', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 25, 2017\nLie: You had millions of people that now aren't insured anymore.\nExplanation: The real number is less than 1 million, according to the Urban Institute.\nURL: https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c34e4716-a2d2-4616-89e1-45dc86495454', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 25, 2017\nLie: So, look, when President Obama was there two weeks ago making a speech, very nice speech. Two people were shot and killed during his speech. You can't have that.\nExplanation: There were no gun homicide victims in Chicago that day.\nURL: https://www.dnainfo.com/chicago/2017-chicago-murders/timeline?mon=1", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='106efd62-59ef-46d7-b10c-3fab6e7c714a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 26, 2017\nLie: We've taken in tens of thousands of people. We know nothing about them. They can say they vet them. They didn't vet them. They have no papers. How can you vet somebody when you don't know anything about them and you have no papers? How do you vet them? You can't.\nExplanation: Vetting lasts up to two years.\nURL: https://www.nytimes.com/interactive/2017/01/29/us/refugee-vetting-process.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c80020d1-a065-4a68-8e53-4ae5e2752f27', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Jan. 26, 2017\nLie: I cut off hundreds of millions of dollars off one particular plane, hundreds of millions of dollars in a short period of time. It wasn't like I spent, like, weeks, hours, less than hours, and many, many hundreds of millions of dollars. And the plane's going to be better.\nExplanation: Most of the cuts were already planned.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='eb7fceb3-0db0-4de6-9e16-36e9ac8a1cc6', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Jan. 28, 2017\nLie: The coverage about me in the @nytimes and the @washingtonpost has been so false and angry that the Times actually apologized to its dwindling subscribers and readers.\nExplanation: It never apologized.\nURL: https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8bc8835a-d57a-466d-87d2-fe459961454a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Jan. 29, 2017\nLie: The Cuban-Americans, I got 84 percent of that vote.\nExplanation: There is no support for this.\nURL: http://www.pewresearch.org/fact-tank/2016/11/15/unlike-other-latinos-about-half-of-cuban-voters-in-florida-backed-trump/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='574ec5c5-a8ad-4ba3-9cf8-6f3465db1287', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Jan. 30, 2017\nLie: Only 109 people out of 325,000 were detained and held for questioning. Big problems at airports were caused by Delta computer outage.\nExplanation: At least 746 people were detained and processed, and the Delta outage happened two days later.\nURL: http://markets.on.nytimes.com/research/stocks/news/press_release.asp?docTag=201701300400PR_NEWS_USPRX____CL99370&feedID=600&press_symbol=7311173', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d7e6a5bf-3c30-4759-bedb-40a8118c61fe', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 3, 2017\nLie: Professional anarchists, thugs and paid protesters are proving the point of the millions of people who voted to MAKE AMERICA GREAT AGAIN!\nExplanation: There is no evidence of paid protesters.\nURL: https://www.nytimes.com/2017/01/28/nyregion/jfk-protests-trump-refugee-ban.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='76773b87-8bf6-4930-af5e-0bcd67d7ff42', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 4, 2017\nLie: After being forced to apologize for its bad and inaccurate coverage of me after winning the election, the FAKE NEWS @nytimes is still lost!\nExplanation: It never apologized.\nURL: https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='281c50c6-fd59-4b9f-a313-3d8cf6e65e76', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 5, 2017\nLie: We had 109 people out of hundreds of thousands of travelers and all we did was vet those people very, very carefully.\nExplanation: About 60,000 people were affected.\nURL: http://www.politifact.com/truth-o-meter/statements/2017/feb/06/donald-trump/president-trump-says-109-people-were-affected-trav/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='fb8cf0f1-aaf6-4d4f-bd6c-ceb8c51c5a15', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 6, 2017\nLie: I have already saved more than $700 million when I got involved in the negotiation on the F-35.\nExplanation: Much of the price drop was projected before Trump took office.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3430b945-8d61-49f8-a69b-115a4b42920b', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 6, 2017\nLie: It's gotten to a point where it is not even being reported. And in many cases, the very, very dishonest press doesn't want to report it.\nExplanation: Terrorism has been reported on, often in detail.\nURL: https://www.nytimes.com/2017/02/07/us/politics/the-white-house-list-of-terror-attacks-underreported-by-media.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='cb83827e-b5be-4fb5-babb-5cae622fc92d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 6, 2017\nLie: The failing @nytimes was forced to apologize to its subscribers for the poor reporting it did on my election win. Now they are worse!\nExplanation: It didn't apologize.\nURL: https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='66abb504-7332-4e46-b561-6b37558cb7ae', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 6, 2017\nLie: And the previous administration allowed it to happen because we shouldn't have been in Iraq, but we shouldn't have gotten out the way we got out. It created a vacuum, ISIS was formed.\nExplanation: The group’s origins date to 2004.\nURL: https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4cdc621c-ff5d-49e3-8260-f1bb8d337a92', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 7, 2017\nLie: And yet the murder rate in our country is the highest it’s been in 47 years, right? Did you know that? Forty-seven years.\nExplanation: It was higher in the 1980s and '90s.\nURL: http://www.politifact.com/truth-o-meter/statements/2017/feb/08/donald-trump/donald-trump-wrong-murder-rate-highest-47-years/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1409dcb7-6d74-4eb4-80a6-cb5f4def9b33', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 7, 2017\nLie: I saved more than $600 million. I got involved in negotiation on a fighter jet, the F-35.\nExplanation: The Defense Department projected this price drop before Trump took office.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b58dff4b-6218-4ca9-84a7-157ac6f04ea0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 9, 2017\nLie: Chris Cuomo, in his interview with Sen. Blumenthal, never asked him about his long-term lie about his brave ‘service’ in Vietnam. FAKE NEWS!\nExplanation: It was part of Cuomo's first question.\nURL: http://transcripts.cnn.com/TRANSCRIPTS/1702/09/nday.05.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1a98128d-59f4-4253-919a-c37c8b28e4eb', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 9, 2017\nLie: Sen. Richard Blumenthal now misrepresents what Judge Gorsuch told him?\nExplanation: The Gorsuch comments were later corroborated.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/02/10/heres-what-trump-got-wrong-on-twitter-this-week-5/?utm_term=.6fbfc4abc6e0', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d60219ea-a0e8-4453-b6f3-8d50bc467ddd', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 10, 2017\nLie: I don’t know about it. I haven’t seen it. What report is that?\nExplanation: Trump knew about Flynn's actions for weeks.\nURL: http://www.factcheck.org/2017/02/trump-spins-flynn-facts/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ed25e910-b554-4838-920b-775d768f966e', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 12, 2017\nLie: Just leaving Florida. Big crowds of enthusiastic supporters lining the road that the FAKE NEWS media refuses to mention. Very dishonest!\nExplanation: The media did cover it.\nURL: http://www.palmbeachpost.com/news/national-govt--politics/trump-heads-back-protesters-supporters-gather/CQXPE9NRk807XKWiDwefWK/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='011f388d-5bb4-4957-a974-d36138ca7f68', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 16, 2017\nLie: We got 306 because people came out and voted like they've never seen before so that's the way it goes. I guess it was the biggest Electoral College win since Ronald Reagan.\nExplanation: George H.W. Bush, Bill Clinton and Barack Obama all won bigger margins in the Electoral College.\nURL: https://www.nytimes.com/2017/02/16/us/politics/trump-fact-check.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a8e65bdb-7c8d-491e-840d-5050687f7e5a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 16, 2017\nLie: That’s the other thing that was wrong with the travel ban. You had Delta with a massive problem with their computer system at the airports.\nExplanation: Delta's problems happened two days later.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/02/03/what-trump-got-wrong-on-twitter-this-week-4/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='03788c4e-6d7f-4438-ad91-8f46eea60a18', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 16, 2017\nLie: Walmart announced it will create 10,000 jobs in the United States just this year because of our various plans and initiatives.\nExplanation: The jobs are a result of its investment plans announced in Oct. 2016.\nURL: https://www.nytimes.com/interactive/2017/business/economy/trump-jobs.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3569f05e-1877-47e0-b0a4-3452c7752f76', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 16, 2017\nLie: When WikiLeaks, which I had nothing to do with, comes out and happens to give, they’re not giving classified information.\nExplanation: Not always. They have released classified information in the past.\nURL: http://www.politifact.com/truth-o-meter/article/2017/feb/16/fact-checking-donald-trumps-press-conference/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e910f0a9-9c60-431a-ae7d-169b81044528', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 16, 2017\nLie: We had a very smooth rollout of the travel ban. But we had a bad court. Got a bad decision.\nExplanation: The rollout was chaotic.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/02/16/fact-checking-president-trumps-news-conference/?utm_term=.517d64230dcf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='fc5f710b-0dc6-4ddf-bdaf-066f4f228c46', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 16, 2017\nLie: They’re giving stuff — what was said at an office about Hillary cheating on the debates. Which, by the way, nobody mentions. Nobody mentions that Hillary received the questions to the debates.\nExplanation: It was widely covered.\nURL: http://www.politifact.com/truth-o-meter/article/2017/feb/16/fact-checking-donald-trumps-press-conference/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='6d2021a0-e62a-4944-ab14-97c8ba408c81', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 18, 2017\nLie: And there was no way to vet those people. There was no documentation. There was no nothing.\nExplanation: Refugees receive multiple background checks, taking up to two years.\nURL: https://www.nytimes.com/interactive/2017/01/29/us/refugee-vetting-process.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='47b9d3bb-e4df-417f-bb9f-fabc5ee8b013', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 18, 2017\nLie: You look at what's happening in Germany, you look at what's happening last night in Sweden. Sweden, who would believe this?\nExplanation: Trump implied there was a terror attack in Sweden, but there was no such attack.\nURL: https://www.nytimes.com/2017/02/19/world/europe/last-night-in-sweden-trumps-remark-baffles-a-nation.html?rref=collection%2Ftimestopic%2FSweden&action=click&contentCollection=world&region=stream&module=stream_unit&version=latest&contentPlacement=7&pgtype=collection", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4ee83688-59ee-4d0f-8edc-6c79119db4f8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 24, 2017\nLie: By the way, you folks are in here — this place is packed, there are lines that go back six blocks.\nExplanation: There was no evidence of long lines.\nURL: http://thehill.com/homenews/administration/320988-trump-falsely-claims-lines-go-back-6-blocks-for-cpac-speech', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='09bb0e80-0589-4762-afce-4949d6780aed', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 24, 2017\nLie: ICE came and endorsed me.\nExplanation: Only its union did.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/oct/10/donald-trump/trump-says-ice-endorsed-him/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='71ba3a24-097d-4554-b312-67fef5618ea5', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 24, 2017\nLie: Obamacare covers very few people — and remember, deduct from the number all of the people that had great health care that they loved that was taken away from them — it was taken away from them.\nExplanation: Obamacare increased coverage by a net of about 20 million.\nURL: https://www.nytimes.com/2017/02/24/us/politics/fact-check-trump-blasts-fake-news-and-repeats-inaccurate-claims-at-cpac.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9f85c0a5-7f42-4bda-bc75-4351884256d7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 27, 2017\nLie: Since Obamacare went into effect, nearly half of the insurers are stopped and have stopped from participating in the Obamacare exchanges.\nExplanation: Many fewer pulled out.\nURL: http://www.heritage.org/health-care-reform/report/the-2017-health-insurance-exchanges-major-decrease-competition-and-choice', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='751423b6-8184-45dc-b270-32c6b44862a4', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 27, 2017\nLie: On one plane, on a small order of one plane, I saved $725 million. And I would say I devoted about, if I added it up, all those calls, probably about an hour. So I think that might be my highest and best use.\nExplanation: Much of the price cut was already projected.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c8966a6a-93bf-4327-8120-ebd60eef3ff7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Feb. 28, 2017\nLie: And now, based on our very strong and frank discussions, they are beginning to do just that.\nExplanation: NATO countries agreed to meet defense spending requirements in 2014.\nURL: https://www.nytimes.com/2017/03/01/us/politics/fact-check-trump-military.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c69bed3f-804c-4fbe-94e6-1181ac4251ad', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 28, 2017\nLie: The E.P.A.’s regulators were putting people out of jobs by the hundreds of thousands.\nExplanation: There's no evidence that the Waters of the United States rule caused severe job losses.\nURL: http://www.nytimes.com/2011/09/05/business/economy/a-debate-arises-on-job-creation-vs-environmental-regulation.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b20363d4-eef7-4be5-b4ff-0ab864cff6c6', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Feb. 28, 2017\nLie: We have begun to drain the swamp of government corruption by imposing a five-year ban on lobbying by executive branch officials.\nExplanation: They can't lobby their former agency but can still become lobbyists.\nURL: https://www.washingtonpost.com/politics/2017/live-updates/trump-white-house/real-time-fact-checking-and-analysis-of-trumps-address-to-congress/fact-check-bans-on-lobbying/?utm_term=.ce1370a2b78d", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='d42b3aa6-0840-429d-901a-3d05ec4bf409', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 3, 2017\nLie: It is so pathetic that the Dems have still not approved my full Cabinet.\nExplanation: Paperwork for the last two candidates was still not submitted to the Senate.\nURL: https://www.washingtonpost.com/news/politics/wp/2017/03/03/trump-is-blaming-the-democrats-for-cabinet-delays-that-are-normal-and-his-own-fault/?utm_term=.68b1395b9ff1', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2144dbd2-90e8-47d6-9a5d-f72e5e34dca8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 4, 2017\nLie: Terrible! Just found out that Obama had my ‘wires tapped’ in Trump Tower just before the victory. Nothing found. This is McCarthyism!\nExplanation: There's no evidence of a wiretap.\nURL: https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ee23431f-a3f0-4e63-a5d6-5173d3d6bd70', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 4, 2017\nLie: How low has President Obama gone to tap my phones during the very sacred election process. This is Nixon/Watergate. Bad (or sick) guy!\nExplanation: There's no evidence of a wiretap.\nURL: https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='52e92cf3-b5a1-4e85-8bb0-c2fd97b7bcc8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 7, 2017\nLie: 122 vicious prisoners, released by the Obama Administration from Gitmo, have returned to the battlefield. Just another terrible decision!\nExplanation: 113 of them were released by President George W. Bush.\nURL: https://www.nytimes.com/2017/03/07/us/politics/guantanamo-bay-trump.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='457b35be-7195-4ea4-9682-11a4496772c8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 13, 2017\nLie: I saved a lot of money on those jets, didn't I? Did I do a good job? More than $725 million on them.\nExplanation: Much of the cost cuts were planned before Trump.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ff84ba17-a029-4c8f-bb2e-83a93b6342a0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 13, 2017\nLie: First of all, it covers very few people.\nExplanation: About 20 million people gained insurance under Obamacare.\nURL: https://www.nytimes.com/2017/03/13/us/politics/fact-check-trump-obamacare-health-care.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7f1a554c-c113-4842-9548-2752038100a7', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 15, 2017\nLie: On the airplanes, I saved $725 million. Probably took me a half an hour if you added up all of the times.\nExplanation: Much of the cost cuts were planned before Trump.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ecd7f3a6-362e-4d86-804a-062a4c849482', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 17, 2017\nLie: I was in Tennessee — I was just telling the folks — and half of the state has no insurance company, and the other half is going to lose the insurance company.\nExplanation: There's at least one insurer in every Tennessee county.\nURL: https://public.tableau.com/profile/kaiser.family.foundation#!/vizhome/InsurerParticipationinthe2017IndividualMarketplace/2017InsurerParticipation", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7b834429-29cb-4cc1-b890-09d81d950551', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 20, 2017\nLie: With just one negotiation on one set of airplanes, I saved the taxpayers of our country over $700 million.\nExplanation: Much of the cost cuts were planned before Trump.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7d4f336c-c39b-4062-858b-f98c4bae9546', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 21, 2017\nLie: To save taxpayer dollars, I’ve already begun negotiating better contracts for the federal government — saving over $700 million on just one set of airplanes of which there are many sets.\nExplanation: Much of the cost cuts were planned before Trump.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='dc6cf075-413d-445d-8ff0-5a823065f9da', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 22, 2017\nLie: I make the statement, everyone goes crazy. The next day they have a massive riot, and death, and problems.\nExplanation: Riots in Sweden broke out two days later and there were no deaths.\nURL: https://www.nytimes.com/2017/02/19/world/europe/last-night-in-sweden-trumps-remark-baffles-a-nation.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='861d3451-515c-4295-9d43-10517b714a65', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 22, 2017\nLie: NATO, obsolete, because it doesn’t cover terrorism. They fixed that.\nExplanation: It has fought terrorism since the 1980s.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/sep/27/donald-trump/donald-trump-wrong-again-about-nato-increasing-ter/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2f8ca77d-03ab-4576-972d-1e967cd991ca', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 22, 2017\nLie: Well, now, if you take a look at the votes, when I say that, I mean mostly they register wrong — in other words, for the votes, they register incorrectly and/or illegally. And they then vote. You have tremendous numbers of people.\nExplanation: There's no evidence of widespread voter fraud.\nURL: https://www.nytimes.com/2017/01/24/us/politics/unauthorized-immigrant-voting-trump-lie.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3f2e0981-6889-4a16-a223-7a6540399cf0', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: March 29, 2017\nLie: Remember when the failing @nytimes apologized to its subscribers, right after the election, because their coverage was so wrong. Now worse!\nExplanation: It didn't apologize.\nURL: https://www.nytimes.com/2016/11/13/us/elections/to-our-readers-from-the-publisher-and-executive-editor.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='32354e18-8a0b-429c-9852-a15baa584076', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: March 31, 2017\nLie: We have a lot of plants going up now in Michigan that were never going to be there if I — if I didn’t win this election, those plants would never even think about going back. They were gone.\nExplanation: These investments were already planned.\nURL: https://www.nytimes.com/interactive/2017/business/economy/trump-jobs.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='54f70c18-208e-44e0-be22-d3a05ba148e2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 2, 2017\nLie: And I was totally opposed to the war in the Middle East which I think finally has been proven, people tried very hard to say I wasn’t but you’ve seen that it is now improving.\nExplanation: He was for an invasion before he was against it.\nURL: https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='672989ab-964f-433c-9911-e6fd87597398', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 2, 2017\nLie: Now, my last tweet — you know, the one that you are talking about, perhaps — was the one about being, in quotes, wiretapped, meaning surveilled. Guess what, it is turning out to be true.\nExplanation: There is still no evidence.\nURL: https://www.nytimes.com/2017/03/04/us/politics/trump-obama-tap-phones.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='122c69cf-b04c-4896-9832-a930fb8b807c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 5, 2017\nLie: You have many states coming up where they’re going to have no insurance company. O.K.? It’s already happened in Tennessee. It’s happening in Kentucky. Tennessee only has half coverage. Half the state is gone. They left.\nExplanation: Every marketplace region in Tennessee had at least one insurer.\nURL: https://www.nytimes.com/2017/03/24/us/politics/fact-check-trumps-misleading-claims-in-health-bill-failure.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='504520c5-7aa5-489f-8736-aee998652e66', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 6, 2017\nLie: If you look at the kind of cost-cutting we’ve been able to achieve with the military and at the same time ordering vast amounts of equipment — saved hundreds of millions of dollars on airplanes, and really billions, because if you take that out over a period of years it’s many billions of dollars — I think we’ve had a tremendous success.\nExplanation: Much of the price cuts were already projected.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3431767a-5860-46df-9e0e-9816e5b73714', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 11, 2017\nLie: I like Steve, but you have to remember he was not involved in my campaign until very late. I had already beaten all the senators and all the governors, and I didn’t know Steve.\nExplanation: He knew Steve Bannon since 2011.\nURL: https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='bd45b2bd-c228-413a-8f24-fe171fc3251f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: April 12, 2017\nLie: You can't do it faster, because they're obstructing. They're obstructionists. So I have people — hundreds of people that we're trying to get through. I mean you have — you see the backlog. We can't get them through.\nExplanation: At this point, he had not nominated anyone for hundreds of positions.\nURL: https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='6aa5c217-4845-48dc-a422-6a6173e48cd9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 12, 2017\nLie: The New York Times said the word wiretapped in the headline of the first edition. Then they took it out of there fast when they realized.\nExplanation: There were separate headlines for print and web, but neither were altered.\nURL: https://www.nytimes.com/2017/03/23/us/politics/fact-check-trump-misleads-surveillance-wiretapping.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3ecef8b5-1a52-479a-a15f-692bfa8b18b2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 12, 2017\nLie: The secretary general and I had a productive discussion about what more NATO can do in the fight against terrorism. I complained about that a long time ago and they made a change, and now they do fight terrorism.\nExplanation: NATO has been engaged in counterterrorism efforts since the 1980s.\nURL: https://www.nytimes.com/2017/04/12/us/politics/trump-steven-bannon-fox-business-news-interview.html?ref=politics', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='37f8ab7a-f69a-4315-a7da-7f9a178aac7c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 12, 2017\nLie: Mosul was supposed to last for a week and now they’ve been fighting it for many months and so many more people died.\nExplanation: The campaign was expected to take months.\nURL: https://www.washingtonpost.com/news/the-fix/wp/2017/04/12/president-trumps-throughly-confusing-fox-business-interview-annotated/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0fe1f015-daaf-4afd-8fd9-59190f54fc90', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: April 16, 2017\nLie: Someone should look into who paid for the small organized rallies yesterday. The election is over!\nExplanation: There's no evidence of paid protesters.\nURL: https://www.nytimes.com/2017/04/15/us/politics/tax-day-march.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9eaa6654-3796-46fd-b3fb-7f71bde899be', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 18, 2017\nLie: The fake media goes, ‘Donald Trump changed his stance on China.’ I haven’t changed my stance.\nExplanation: He did.\nURL: https://www.nytimes.com/2017/04/14/business/china-currency-manipulation-trump.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='80e25332-203a-49bb-a7a4-e9f142dbc9c2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: April 21, 2017\nLie: On 90 planes I saved $725 million. It's actually a little bit more than that, but it's $725 million.\nExplanation: Much of the price cuts were already projected.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/01/31/trumps-claim-taking-credit-for-cutting-600-million-from-the-f-35-program/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='ccc3d0b3-1f34-4408-8490-e87c853efb15', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 21, 2017\nLie: When WikiLeaks came out ... never heard of WikiLeaks, never heard of it.\nExplanation: He criticized it as early as 2010.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/04/25/fact-checking-president-trumps-pinocchio-laden-associated-press-interview/?utm_term=.33ae871d0c9c', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='df175209-84d6-4a14-8e96-3c1f05c8b7e8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: April 27, 2017\nLie: I want to help our miners while the Democrats are blocking their healthcare.\nExplanation: The bill to extend health benefits for certain coal miners was introduced by a Democrat and was co-sponsored by mostly Democrats.\nURL: http://www.pbs.org/newshour/rundown/retired-coal-miners-get-health-care-fix-pension-problems-remain/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  Document(id_='25b680e4-16e8-4b0c-98ec-376cca82fa48', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 7, 2017\nLie: We're the highest-taxed nation in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e1d4f62e-b719-4cd6-86fe-c4c6d9c59cb6', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 7, 2017\nLie: The Coast Guard, in Texas, and all over, but with the job they did in Texas, I saw, they saved 16,000 lives.\nExplanation: The real number is smaller.\nURL: https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='bad69674-7e20-4904-b2e3-88c845523f30', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 7, 2017\nLie: Obama should have never gotten out the way he got out. That's how ISIS formed.\nExplanation: The group’s origins date to 2004.\nURL: https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='45c81c90-1e1a-4bd0-bae5-43e96618ded8', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 10, 2017\nLie: The Failing @nytimes set Liddle' Bob Corker up by recording his conversation. Was made to sound a fool, and that's what I am dealing with!\nExplanation: Corker asked the Times reporter to record the call; his aides recorded it too.\nURL: https://www.nytimes.com/2017/10/10/reader-center/trump-claims-we-tricked-bob-corker-heres-the-truth.html?_r=0", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='15e25e1a-cad9-4fbb-a4fa-edceeafd6656', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 10, 2017\nLie: We're the highest-taxed nation in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='a6b6f9ad-c3e6-4d37-a8e2-9c61142c830a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 11, 2017\nLie: We have missiles that can knock out a missile in the air. Ninety seven per cent of the time. If you send two of them, it's going to get knocked out.\nExplanation: The effectiveness rate is about 60 percent.\nURL: https://warontherocks.com/2017/10/deadly-overconfidence-trump-thinks-missile-defenses-work-against-north-korea-and-that-should-scare-you/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='407a06e6-0411-40a4-a5a7-564d7f16ac75', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 16, 2017\nLie: We're the highest-taxed country in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='21100e34-02f4-4f78-8642-dae08e630020', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 16, 2017\nLie: I hear that Ireland is going to be reducing their corporate rates down to 8 percent from 12.\nExplanation: Ireland has no plans to cut its tax rate.\nURL: https://www.snopes.com/trump-ireland-tax/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='49565aae-575d-4469-8f70-de231b0425e9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 16, 2017\nLie: If you look at President Obama and other presidents, most of them didn’t make calls.\nExplanation: They did call families of soldiers killed in action.\nURL: https://www.nytimes.com/2017/10/16/us/politics/trump-obama-killed-soldiers.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='f21480ed-1cf4-4ca1-834b-938603c56895', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 16, 2017\nLie: All I can say is it's totally fake news, just fake. It's fake. It's made-up stuff, and it's disgraceful what happens, but that happens in the world of politics.\nExplanation: Trump himself has bragged about groping women.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/10/27/trump-says-sex-harassment-claims-are-fake-news-but-there-are-corroborators/?utm_term=.23c3b28384e2", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='2baab0ae-4e7b-4c88-9c80-2854c6bac238', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: We're the highest taxed nation in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3d2a5feb-a5e9-4214-9883-8d6915f37f41', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: Right now, we are the highest-taxed nation anywhere in the world. You can even say developed or undeveloped.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1dbf399f-8eba-4468-aea8-13744c737c64', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: As far as I'm concerned, I think we're really essentially the highest. But if you'd like to add the developed nation, you can say that, too.\nExplanation: Taxes in the U.S. are lower than in most developed countries.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='91d5a4a8-355b-4e7c-b005-3d359c10e9d2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: We're the highest-taxed nation in the world. We are taxed beyond belief.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='bbb3a659-3d1b-4128-be4f-edb9c2d1f9a6', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: Well, we're the highest-taxed nation in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='056d755a-6ac1-43cc-a2c6-5069a52d28d9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 17, 2017\nLie: I wish President Obama didn't get out the way he got out. Because that left a vacuum and ISIS was formed.\nExplanation: The group’s origins date to 2004.\nURL: https://www.nytimes.com/2015/11/19/world/middleeast/in-rise-of-isis-no-single-missed-key-but-many-strands-of-blame.html", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='27780d54-8ce0-4309-ac5c-b08c21d6901f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Oct. 18, 2017\nLie: Democrat Congresswoman totally fabricated what I said to the wife of a soldier who died in action (and I have proof).\nExplanation: The wife confirmed Representative Frederica Wilson's account.\nURL: http://time.com/4993045/myeshia-johnson-donald-trump-frederica-wilson/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='14ca6dac-600e-4b1d-a5f7-d1868eea053f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 18, 2017\nLie: The Coast Guard in Texas saved 16,000 lives.\nExplanation: The real number was smaller.\nURL: https://content.govdelivery.com/accounts/USDHSCG/bulletins/1b5ace3', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='f9510b47-7f9f-41bd-aef2-c3fb77f228ea', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 18, 2017\nLie: Nobody has ever heard of a five hitting land.\nExplanation: Category 5 storms have hit land before.\nURL: http://www.cnn.com/2017/09/07/us/three-category-5-hurricanes-landfall-trnd/index.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b807e98a-30c6-45be-8276-8bb8720d3438', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 24, 2017\nLie: Under our plan, more than 30 million Americans who own small businesses will get a 40 per cent cut to their top marginal tax rate.\nExplanation: The real number is estimated to be less than 1 million.\nURL: http://www.businessinsider.com/trump-small-business-tax-cut-pass-through-s-corporations-2017-10', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='85ed2f2e-39d5-4f75-8931-69d505455375', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 25, 2017\nLie: We have trade deficits with almost everybody.\nExplanation: We have trade surpluses with more than 100 countries.\nURL: https://www.bea.gov/newsreleases/international/trade/2017/trad0917.htm', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7bcee839-a721-4ab7-bd55-352d32af8a27', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Oct. 27, 2017\nLie: Wacky & totally unhinged Tom Steyer, who has been fighting me and my Make America Great Again agenda from beginning, never wins elections!\nExplanation: Steyer has financially supported many winning candidates.\nURL: https://www.opensecrets.org/donor-lookup/results?name=Thomas+Steyer', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='0b9947d6-0056-458d-900e-12bd12562f53', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Nov. 1, 2017\nLie: Again, we're the highest-taxed nation, just about, in the world.\nExplanation: We're not.\nURL: http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='4ea27856-ae88-4b5d-8021-bc31ba3e1e33', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Date: Nov. 7, 2017\nLie: When you look at the city with the strongest gun laws in our nation, it's Chicago.\nExplanation: Several other cities, including New York and Los Angeles, have stronger gun laws.\nURL: http://www.politifact.com/truth-o-meter/statements/2017/nov/07/donald-trump/trump-wrongly-repeats-chicago-has-strongest-gun-la/", mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='bb5ceda0-7a7f-4044-ab71-5efb86e7406d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Date: Nov. 11, 2017\nLie: I\'d rather have him  – you know, work with him on the Ukraine than standing and arguing about whether or not  – because that whole thing was set up by the Democrats.\nExplanation: There is no evidence that Democrats "set up" Russian interference in the election.\nURL: https://www.nytimes.com/interactive/2017/12/10/us/politics/trump-and-russia.html', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
from llama_index.core import VectorStoreIndex

# %%
# Create the index
index = VectorStoreIndex.from_documents(documents)

# %%
# Create a query engine
query_engine = index.as_query_engine()

# %%
# Query the index
response = query_engine.query("What lies are documented related to Russia?")
print(response)
# Out:
# Two lies related to Russia are documented.

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='63ff1e97-3d4f-41b0-8895-4978a1c44c25', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7aa4a693-d281-4fc6-8172-62f5c8335230', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5656bcb477194a313294882e6a64919360f81a4dfe1b0829da08e9169f7d5ed0')}, text="Date: Aug. 3, 2017\nLie: The Russia story is a total fabrication.\nExplanation: It's not.\nURL: https://www.washingtonpost.com/news/fact-checker/wp/2017/08/03/fact-checking-the-trump-russia-investigation/?utm_term=.1404a36076a6", mimetype='text/plain', start_char_idx=0, end_char_idx=224, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.8442507833505157),
#  NodeWithScore(node=TextNode(id_='eb65fb24-a2cc-4d03-aa2a-e50a6a2967a3', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='89d16b53-ae57-4ab9-8230-bfe0d6dd531c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='6e185826f189df9b26e7bfa2da801b391ba177669f979b666243241fa858a9f6')}, text='Date: May 12, 2017\nLie: Again, the story that there was collusion between the Russians & Trump campaign was fabricated by Dems as an excuse for losing the election.\nExplanation: The F.B.I. was investigating before the election.\nURL: https://www.nytimes.com/interactive/2017/05/10/us/politics/fbi-congress-trump-russia-investigations.html', mimetype='text/plain', start_char_idx=0, end_char_idx=337, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.823990230439117)]

# %%
from llama_index.core import Document, VectorStoreIndex, HTMLReader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_index.core import Document, VectorStoreIndex, HTMLReader
#
# ImportError: cannot import name 'HTMLReader' from 'llama_index.core' (D:\anaconda3\Lib\site-packages\llama_index\core\__init__.py)
